# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize
import DataA

# %% [markdown]
# # Big Moon Data

# %%
D = np.load("big_moonfinal.npz")["volts"]
T = np.load("big_moonfinal.npz")["time"]

# %%
plt.plot(T,D)
plt.show()

# %%
Sig = np.fft.fft(D)
n = len(D)
timestep = 1 #second
freq = np.fft.fftfreq(n, d=timestep)

# %%
plt.plot(freq,abs(Sig)**0.5)

# %%
V_spec = np.fft.fft(D)
P_moon = abs(V_spec)**2
sampling_freq = 1 #Hz
f = np.fft.fftfreq(len(D),1/sampling_freq)

# %%
#%matplotlib notebook
plt.plot(np.fft.fftshift(f),np.fft.fftshift(P_moon))

# %%
V_filtered = V_spec
for i in range (0,len(P_moon)):
    if (f[i]>-0.04) and (f[i]<-0.02):
        V_filtered[i] = V_spec[i]
    if (f[i]<0.04) and (f[i]>0.02):
        V_filtered[i] = V_spec[i]
    else:
        V_filtered[i] = 0

# %%
plt.plot(np.fft.fftshift(V_spec))
# Out:
# /Users/costassoler/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
v_filtered = np.fft.ifft(V_spec)

# %%
T[0]+9200
# Out:
# 1552526757.014736

# %%
plt.plot(T-T[0],v_filtered)
plt.title('Signal vs Time')
plt.xlabel('Time (Seconds)')
plt.ylabel('Signal')

plt.savefig('SigVsTime.pdf')
plt.show()
# Out:
# /Users/costassoler/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Calculating Range of Fringe Frequencies

# %%
RaStart = (15-5)*180//12
RaEnd = (24-5)*180//12
HA = np.arange(RaStart,RaEnd)
B = 20
lam = (3*10**8)/(10.7*10**9)
delta = 18*(np.pi/180) #degrees
L = 37.87*(np.pi/180)
hs = HA*(np.pi/180) #noon
ff = (B/lam)*np.cos(delta)*np.cos(hs) - (B/lam)*np.sin(L)*np.cos(delta)*np.sin(hs)
F = ff*2*np.pi/(24*3600)
plt.plot(HA,F)
plt.title('Moon Fringe Frequency vs. Hour Angles')
plt.ylabel('Fringe Frequency (Hz)')
plt.xlabel('Hour Angle')
# Out:
# Text(0.5,0,'Hour Angle')

# %% [markdown]
# ## All our fringes lie within this range

# %% [markdown]
# # 10 Calculating width of moon

# %%
y1 = 2400 #times at which the "bessel function" goes to zero
y2 = 9200
Y = [y1,y2]

hi = 15*3600



h1 = hi+y1
h2 = hi+y2

xdata = [h1,h2]
ydata = [y1,y2]

def func(x, R):
    B = 20
    lam = (3*10**8)/(10.7*10**9)
    
    return (B/lam)*np.cos(x)/R

# %%
import scipy.optimize as optimization
c = optimization.curve_fit(func, xdata, ydata)[0]
c
# Out:
# array([2770013.10631212])

# %% [markdown]
# # Bessel Function (compare moon roots to J1/x roots)

# %%
j_roots = [3.83,7.83]#[10.17,13.32]

 #these are the hour angles of the moon at the null locations in radians
def u(ha):
    B = 20
    lam = (3*10**8)/(10.7*10**9)
    u = np.cos(ha)*B/lam
    return u

# %%
HA1 = (18.5-16.5)*np.pi/12
HA2 = (18.5-18.25)*np.pi/12

# %%
U_vals = [u(HA1),u(HA2)]

# %%
LS = np.polyfit(U_vals,j_roots,1)

# %%
R = LS[0]/(2*np.pi)
print(R*2*180/np.pi)
U_vals
# Out:
# 0.7757367854221777
# [617.7647880328997, 711.8060319102038]

# %% [markdown]
# # 8.4 Least Squares Fitting the Fringe to the baselines

# %%
B = 20
l = (3*10**8)/(10.7*10**9)

1700*l/B
# Out:
# 2.3831775700934577

# %%
1/1700
# Out:
# 0.000588235294117647

# %% [markdown]
# # Long Sun Data:

# %%
VBS = np.load('Sun2019final.npz')['volts']
TBS = np.load('Sun2019final.npz')['time']

# %%
plt.plot(TBS,VBS)
plt.show()

# %%
Sig = np.fft.fft(VBS)
n = len(VBS)
timestep = 1 #second
freq = np.fft.fftfreq(n, d=timestep)

# %%
#%matplotlib notebook

plt.plot(freq,abs(Sig)**2)

# %%
Bound = [[-0.04,-0.034],[0.034,0.04]]
FILTERED = DataA.Filter(freq,abs(Sig)**2,Bound)

# %%
plt.plot(freq,FILTERED)

# %%
Sig_Filtered = np.fft.fft(FILTERED)
#Time = np.fft.fftfreq(freq)
T = TBS-TBS[0]

plt.plot(TBS,Sig_Filtered)
# Out:
# /Users/costassoler/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Least Squares Fitting for Baseline

# %% [markdown]
# ### Let's extract a small portion to only look at the high frequencies caused by baseling and dec:

# %%
LSFSignal = []
LSFTime = []
for i in range (0,len(TBS)):
    if (8250<T[i]) and (T[i]<8500):
        LSFTime.append(T[i]+TBS[0])
        LSFSignal.append(Sig_Filtered[i])

# %%
LSFTime
# Out:
# [1552856312.51284,
#  1552856313.46695,
#  1552856314.467162,
#  1552856315.496018,
#  1552856316.47001,
#  1552856317.566162,
#  1552856318.467032,
#  1552856319.466889,
#  1552856320.468035,
#  1552856322.463983,
#  1552856324.463867,
#  1552856326.46915,
#  1552856327.46698,
#  1552856328.467059,
#  1552856329.476676,
#  1552856330.497324,
#  1552856331.486897,
#  1552856332.467215,
#  1552856333.496645,
#  1552856334.467118,
#  1552856335.50411,
#  1552856336.574936,
#  1552856337.466918,
#  1552856338.467066,
#  1552856339.488433,
#  1552856341.463831,
#  1552856342.467245,
#  1552856343.467305,
#  1552856347.503678,
#  1552856348.467226,
#  1552856349.467131,
#  1552856351.464064,
#  1552856359.472007,
#  1552856361.506537,
#  1552856362.466945,
#  1552856363.500698,
#  1552856364.551747,
#  1552856365.492559,
#  1552856366.466907,
#  1552856367.467132,
#  1552856368.467074,
#  1552856369.467363,
#  1552856370.497183,
#  1552856371.543943,
#  1552856372.46754,
#  1552856373.470371,
#  1552856374.467325,
#  1552856376.463868,
#  1552856377.467039,
#  1552856378.467026,
#  1552856379.467113,
#  1552856381.476045,
#  1552856382.467272,
#  1552856383.46705,
#  1552856384.534813,
#  1552856386.463914,
#  1552856387.467288,
#  1552856388.466901,
#  1552856389.564471,
#  1552856391.495973,
#  1552856392.466429,
#  1552856393.467316,
#  1552856394.467329,
#  1552856395.512182,
#  1552856397.463864,
#  1552856398.476275,
#  1552856399.46669,
#  1552856401.463963,
#  1552856402.466594,
#  1552856403.46701,
#  1552856404.521506,
#  1552856405.496305,
#  1552856406.47459,
#  1552856407.467471,
#  1552856408.474013,
#  1552856409.546851,
#  1552856410.4977,
#  1552856411.467122,
#  1552856412.512331,
#  1552856413.578071,
#  1552856414.467377,
#  1552856416.495798,
#  1552856417.473774,
#  1552856418.467148,
#  1552856422.467836,
#  1552856423.517161,
#  1552856424.467289,
#  1552856426.465984,
#  1552856427.501585,
#  1552856428.467204,
#  1552856429.47079,
#  1552856431.468035,
#  1552856432.467316,
#  1552856433.467219,
#  1552856434.49207,
#  1552856435.496883,
#  1552856436.467075,
#  1552856438.518294,
#  1552856439.467091,
#  1552856440.496741,
#  1552856441.46713,
#  1552856442.5048,
#  1552856444.466257,
#  1552856446.46379,
#  1552856447.571741,
#  1552856448.467033,
#  1552856449.498149,
#  1552856450.497304,
#  1552856451.467146,
#  1552856452.467131,
#  1552856453.467051,
#  1552856454.467136,
#  1552856462.480259,
#  1552856463.49367,
#  1552856464.467086,
#  1552856466.468133,
#  1552856467.467164,
#  1552856468.467261,
#  1552856469.502609,
#  1552856470.515698,
#  1552856471.53809,
#  1552856472.467028,
#  1552856473.471341,
#  1552856474.470284,
#  1552856475.497015,
#  1552856476.467079,
#  1552856477.514162,
#  1552856478.467051,
#  1552856482.524081,
#  1552856483.467286,
#  1552856484.467125,
#  1552856486.495934,
#  1552856487.565128,
#  1552856488.467058,
#  1552856489.467126,
#  1552856491.497831,
#  1552856493.463915,
#  1552856494.467113,
#  1552856496.463933,
#  1552856497.492514,
#  1552856498.474374,
#  1552856499.467031,
#  1552856500.468462,
#  1552856501.467226,
#  1552856502.479009,
#  1552856503.474612,
#  1552856504.516066,
#  1552856505.497577,
#  1552856506.46694,
#  1552856507.541828,
#  1552856508.467126,
#  1552856509.467189,
#  1552856511.463885,
#  1552856512.548741,
#  1552856513.46704,
#  1552856514.470744,
#  1552856516.463899,
#  1552856517.485049,
#  1552856518.467029,
#  1552856519.503585,
#  1552856521.473381,
#  1552856522.467187,
#  1552856523.474574,
#  1552856524.46711,
#  1552856525.496834,
#  1552856526.47154,
#  1552856527.470763,
#  1552856528.467197,
#  1552856529.467361,
#  1552856531.464261,
#  1552856532.467197,
#  1552856533.530349,
#  1552856534.476591,
#  1552856535.496859,
#  1552856536.466921,
#  1552856537.46703,
#  1552856538.467109,
#  1552856539.467324,
#  1552856540.497897,
#  1552856541.467133,
#  1552856542.467193,
#  1552856543.468426,
#  1552856544.54163,
#  1552856545.497818,
#  1552856546.46728,
#  1552856547.467241,
#  1552856548.475593,
#  1552856549.48893,
#  1552856550.498772,
#  1552856551.467209,
#  1552856552.467286,
#  1552856553.471166,
#  1552856554.466994,
#  1552856555.508955,
#  1552856556.562666,
#  1552856557.46703,
#  1552856558.467176,
#  1552856559.4734,
#  1552856561.46393]

# %%
plt.plot(np.array(LSFTime),np.array(LSFSignal))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/costassoler/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
#        -2.37154325-1.73716413e-15j, -3.68481917+1.08609354e-15j,
#        -4.79365915-2.50618280e-15j, -5.63652278+6.92007079e-16j,
#        -6.16664714-1.31252836e-15j, -6.35463973-2.44480687e-15j,
#        -6.19010555-1.56799091e-15j, -5.68221827-1.25569237e-15j,
#        -4.85920443-2.70212444e-15j, -3.76676979-2.97200476e-15j,
#        -2.46555599+4.13464100e-16j, -1.02776919-1.22311727e-16j,
#         0.46683144+1.27315317e-15j,  1.9353623 +9.24710433e-16j,
#         3.2964149 +1.67182863e-15j,  4.47457081+3.57756512e-15j,
#         5.40458162+2.14587542e-15j,  6.03498198+5.14748537e-16j,
#         6.33093592+3.78733984e-15j,  6.27615892+3.63684215e-16j,
#         5.87380983+3.01499831e-15j,  5.14630426+2.20539510e-15j,
#         4.13406034-2.26877453e-15j,  2.89324765+5.99499736e-16j,
#         1.49266478-1.03614800e-15j,  0.0099196 -1.93566943e-15j,
#        -1.47287554-8.69137686e-16j, -2.87365453-5.18580218e-16j,
#        -4.11494178-1.55622496e-15j, -5.1281382 -3.00849846e-15j,
#        -5.85731186-2.38698757e-15j, -6.26228371-1.77788202e-15j,
#        -6.32083832-1.45541278e-15j])

# %%
ha_init = -6*3600
ha_final = ha_init+len(VBS)
HA = np.arange(ha_init,ha_final)
import BaselineDec

# %% [markdown]
# ## Trying Scipy:

# %%
def HA(Start,Data,FirstHa,Ra):
    '''
    Arguments: Data, FirstHa
    Data is your list of ifm timestamps, in unix time.
    FirstHa: the hour hangle of your source at the first timestamp
    (use an online converter to go from Unix time to PDT to LST to HA, 
    and Make sure this is in Radians!)
    Ra = source's right ascension
    '''
    L = []
    
    for i in range (0,len(Data)):
        Step = (Data[i]-Start)*np.pi/(12*3600)
        L.append(FirstHa+Step-Ha)
    return np.array(L)

# %%
FirstHa = (15*np.pi/12)+(10*np.pi/(12*60))+(59*np.pi/(12*3600))
Ha = (23*np.pi/12)+(47*np.pi/(12*60))+(40*np.pi/(12*3600))

# %%
Wee = HA(TBS[0],TBS,FirstHa,Ha)

# %%
X_Data = Wee
Y_Data = VBS
scipy.optimize.curve_fit(BaselineDec.FringeAmplitude,X_Data,Y_Data*100)
#FringeAmplitude(X_Data,B)
# Out:
# (array([1.25058365, 1.12305979]), array([[960.12901052, 368.73790235],
#         [368.73790235, 141.61392807]]))

# %%
# %matplotlib notebook
plt.plot(Wee,BaselineDec.FringeAmplitude(X_Data,2.288,1.41))
plt.plot(Wee,VBS*100)

# %% [markdown]
# ## Same Process, but with a small section:

# %%
np.abs(np.array(LSFSignal))
# Out:
# array([5.07485781, 4.51814904, 3.70434731, 2.67861223, 1.49819499,
#        0.22924206, 1.056911  , 2.28774788, 3.39365705, 4.31186435,
#        4.98999074, 5.38903389, 5.48560407, 5.27328665, 4.76305209,
#        3.98268795, 2.97528233, 1.79684159, 0.51317429, 0.8037853 ,
#        2.08000859, 3.24353316, 4.22851835, 4.97896785, 5.4519086 ,
#        5.61984605, 5.47235559, 5.01671836, 4.27756331, 3.29553268,
#        2.12504373, 0.83126983, 0.51349135, 1.83385998, 3.05560055,
#        4.10979566, 4.93673242, 5.4892824 , 5.73558389, 5.66087405,
#        5.26836576, 4.57911747, 3.63090081, 2.47612687, 1.17894533,
#        0.18832307, 1.54922183, 2.82743674, 3.95107699, 4.85671916,
#        5.49298664, 5.82346234, 5.82876984, 5.50770403, 4.87734561,
#        3.97215057, 2.84206323, 1.54975645, 0.16715152, 1.22858855,
#        2.55936922, 3.75053692, 4.73506898, 5.45734578, 5.87629266,
#        5.96771421, 5.72568829, 5.16293965, 4.31017003, 3.21438001,
#        1.93627453, 0.54689554, 0.87633135, 2.25391582, 3.50874636,
#        4.57040969, 5.3791441 , 5.88920448, 6.07144961, 5.91500537,
#        5.427909  , 4.63669647, 3.5849542 , 2.33091413, 0.94422534,
#        0.49791897, 1.91508308, 3.2280794 , 4.3633969 , 5.25731968,
#        5.85950468, 6.13581762, 6.07026724, 5.66592841, 4.94480086,
#        3.94660991, 2.72661461, 1.35254447, 0.09916509, 1.54762928,
#        2.91202495, 4.11610445, 5.09245989, 5.78629917, 6.15852216,
#        6.18792425, 5.87240307, 5.2290997 , 4.29346546, 3.11730499,
#        1.76590398, 0.31440093, 1.15639508, 2.56450761, 3.83136593,
#        4.8861925 , 5.66995974, 6.13869471, 6.26594663, 6.04427872,
#        5.48570033, 4.6210143 , 3.49811521, 2.17933265, 0.73796725,
#        0.74578795, 2.18931346, 3.51216771, 4.640573  , 5.5115327 ,
#        6.07634969, 6.30334959, 6.17965637, 5.71192083, 4.9259609 ,
#        3.86533337, 2.58891611, 1.16763542, 0.31947948, 1.78969503,
#        3.16117983, 4.35756254, 5.31218688, 5.97182674, 6.29965409,
#        6.27729429, 5.90585409, 5.20586491, 4.21614446, 2.99164007,
#        1.6003737 , 0.11965884, 1.36820006, 2.78048617, 4.03867192,
#        5.07278751, 5.82531316, 6.25437844, 6.33609079, 6.06586381,
#        5.45867148, 4.54821454, 3.38504557, 2.03375738, 0.5693914 ,
#        0.92673403, 2.37154325, 3.68481917, 4.79365915, 5.63652278,
#        6.16664714, 6.35463973, 6.19010555, 5.68221827, 4.85920443,
#        3.76676979, 2.46555599, 1.02776919, 0.46683144, 1.9353623 ,
#        3.2964149 , 4.47457081, 5.40458162, 6.03498198, 6.33093592,
#        6.27615892, 5.87380983, 5.14630426, 4.13406034, 2.89324765,
#        1.49266478, 0.0099196 , 1.47287554, 2.87365453, 4.11494178,
#        5.1281382 , 5.85731186, 6.26228371, 6.32083832])

# %%
def Test(Data, A,B,C ):
    Out = []
    for i in range (0,len(Data)):
        F = A*np.sin(B*Data[i]+C)
        Out.append(F)
        
    return Out

def Test_function(Data,A,B,C):
    Y = A*np.cos(B*np.sin(Data)+C)
    return Y

# %%
X_Data = HA(TBS[0],LSFTime,FirstHa,Ha)
Y_Data = np.real(np.array(LSFSignal))
params,covar = scipy.optimize.curve_fit(Test_function,X_Data,Y_Data)

# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0,'Hour Angle')

# %%
#X = np.arange(0,20,0.1)
def Test_function(Data):
    Y = np.cos(A*np.sin(Data))
    return Y
#plt.plot(X_Data,Test_function(X_Data))
#print(X_Data)

# %%
params,covar = scipy.optimize.curve_fit(Test_function,X _Data,Y_Data)
# Out:
#   File "<ipython-input-143-87d40d37632d>", line 1
#     params,covar = scipy.optimize.curve_fit(Test_function,X _Data,Y_Data)
#                                                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Finding the Source Declination

# %%
params,covar = scipy.optimize.curve_fit(Test_function,X _Data,Y_Data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-07b0325fdced> in <module>()
# ----> 1 params,covar = scipy.optimize.curve_fit(Test_function,X_Data,Y_Data)
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     685         args, varargs, varkw, defaults = _getargspec(f)
#     686         if len(args) < 2:
# --> 687             raise ValueError("Unable to determine number of fit parameters.")
#     688         n = len(args) - 1
#     689     else:
#
# ValueError: Unable to determine number of fit parameters.

# %%
plt.plot(T-T[0],v_filtered)
plt.title('Signal vs Time')
plt.xlabel('Time (Seconds)')
plt.ylabel('Signal')

plt.savefig('SigVsTime.pdf')
plt.show()

# %% [markdown]
# # HANDOUT ATTEMPT:

# %%
A = np.empty((100,75), dtype=object)
Res = np.empty((100,75))
var = np.empty((100,75), dtype=object)
ewVals = np.linspace(15,20,100)
nsVals = np.linspace(0,1,75)
Y = VBS[0:100]
Y.shape = (-1,1)
hs = HA(TBS[0],TBS,FirstHa,Ha)[0:100]
d = np.pi/2 #GUESS for sun
L = 37.87*np.pi/180
for i in range (0,len(ewVals)):
    for j in range(0,len(nsVals)):
        Bew = ewVals[i]
        Bns = nsVals[j]
        lam = (3*10**8)/(10.7*10**9)
        Qew = Bew*np.cos(d)/lam
        Qns = Bns*np.sin(L)*np.cos(d)
        vT = Qew*np.sin(hs)+Qns*np.cos(hs)
        ATerm = np.cos(2*np.pi*vT)
        BTerm = np.sin(2*np.pi*vT)
        XT = np.vstack((ATerm,BTerm)) #gives you (Aterm1,Bterm1)RETURN(Aterm2,Bterm2) etc
        X = XT.T
        XX = np.dot(X.T,X)
        XY = np.dot(X.T,Y)
        XXI = np.linalg.inv(XX)
        a = np.dot(XXI,XY)
        A[i,j] = a

        YBAR = np.dot(X,a)
        DELY = Y-YBAR
        s_sq = np.dot(DELY.T, DELY)/(len(Y)-2)
        Res[i,j] = s_sq

# %%
np.where(Res==Res.min())
# Out:
# (array([0]), array([0]))

# %%
print(np.unravel_index(Res.argmin(), Res.shape))
# Out:
# (0, 0)

# %%
Res[0,73]
# Out:
# 1.11922320196842e-06

# %%
Res.min()
# Out:
# 1.1192231304052132e-06

# %%
Res[73,0]
# Out:
# 1.1192231304052151e-06

# %%
Res.shape
# Out:
# (100, 75)

# %%
ewVals[73]
# Out:
# 22.373737373737374
